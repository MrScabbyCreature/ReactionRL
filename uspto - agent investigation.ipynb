# %%
from ChemRL import ChemRlEnv
from action_wrapper import MoleculeEmbeddingsActionWrapper

import rewards.properties as reward
from rdkit import Chem
import argparse, os, tqdm
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import display

import action_utils

# %% [markdown]
# I sample a random molecule. Then plot the reward distribution acc. to all applicable actions. Then I plot the reward distribution of the agent's learnt action distribution.
#
# The agent does tend to learn the better actions.

# %%
def applicable_action_distribution(plot=True):
    print(f"{applicable_actions.shape[0]} applicable actions...")

    qed_change_for_applicable_actions = []
    for i in tqdm.tqdm(range(applicable_actions.shape[0])):
        action = applicable_actions.iloc[i]
        qed_change_for_applicable_actions.append(reward.qed(action_utils.apply_action(start_mol, *action)) - initial_qed)

    print(f"mean = {np.mean(qed_change_for_applicable_actions)}, std={np.std(qed_change_for_applicable_actions)}")
    bins = np.histogram_bin_edges(qed_change_for_applicable_actions, bins="auto")
    sns.histplot(qed_change_for_applicable_actions, bins=bins)
    if plot:
        plt.show()
    return bins

def agent_distribution(bins="auto", plot=True):
    qed_change_for_agent = []

    # Sample a bunch of times and plot distribution
    for i in tqdm.tqdm(range(applicable_actions.shape[0])):
        # Get an action for the original obs
        action, _ = agent.predict(obs)

        # reset env to have the original mol as state
        env.reset(seed=seed)

        # get new state mol and measure change in qed
        env.step(action)
        qed_change_for_agent.append(reward.qed(env.state) - initial_qed)

    print(f"mean = {np.mean(qed_change_for_agent)}, std={np.std(qed_change_for_agent)}")
    sns.histplot(qed_change_for_agent, bins=bins)
    if plot:
        plt.show()


for i in range(100):
    seed = np.random.randint(2**32)
    env = MoleculeEmbeddingsActionWrapper(ChemRlEnv(render_mode="all"))
    obs, info = env.reset(seed=seed, return_info=True)
    initial_qed = reward.qed(start_mol)

    # Start mol
    start_mol = Chem.Mol(env.state)
    display(env.state)

    # Get applicable actions
    applicable_actions = action_utils.get_applicable_actions(start_mol)

    bins = applicable_action_distribution()

    agent_distribution(bins=bins)
    
    print("="*200)
# Out:
# 8 applicable actions...
# 100%|█████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 261.53it/s]
# mean = 0.29825836533644007, std=0.0878433769902538
# 100%|██████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 12.10it/s]
# mean = 0.11311973178585918, std=0.0
# ...
# 162 applicable actions...
# 100%|█████████████████████████████████████████████████████████████| 162/162 [00:00<00:00, 408.98it/s]
# mean = -0.03688255245653971, std=0.1313819926259728
# 100%|██████████████████████████████████████████████████████████████| 162/162 [00:11<00:00, 13.55it/s]
# mean = 0.09505761294297066, std=0.0
# ...
# 11 applicable actions...
# 100%|███████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 203.70it/s]
# mean = 0.09201001819142238, std=0.17973040250868064
# 100%|████████████████████████████████████████████████████████████████| 11/11 [00:01<00:00,  9.15it/s]
# mean = -0.0705931665787205, std=0.0
# ...
